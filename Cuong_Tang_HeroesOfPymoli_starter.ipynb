# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# Raw data file
file_to_load = "Resources/purchase_data.csv"

# Read purchasing file and store into pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total_player = purchase_data["SN"].nunique()
total_player
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_items = purchase_data["Item Name"].nunique()
unique_items

average_price = purchase_data["Price"].mean()
average_price

number_phurchase = purchase_data["Purchase ID"].count()
number_phurchase

total_revenue = purchase_data["Price"].sum()
total_revenue

summary_table = pd.DataFrame({"Average Price": [average_price],
                              "Number of Purchases": [number_phurchase],
                              "Number of Unique Items": [unique_items],
                              "Total Revenue": [total_revenue]})
summary_table
# Out:
#    Average Price  Number of Purchases  Number of Unique Items  Total Revenue
# 0       3.050987                  780                     179        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_count = purchase_data["Gender"].value_counts()
gender_count

gender_percentage = (gender_count/total_player)*100
gender_percentage

gender_table = pd.DataFrame({"Total Count": gender_count, "Percentage of Players": gender_percentage})
gender_table
# Out:
#                        Total Count  Percentage of Players
# Male                           652             113.194444
# Female                         113              19.618056
# Other / Non-Disclosed           15               2.604167

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
gender_purchase_count = purchase_data.groupby(['Gender']).count()["Purchase ID"].rename("count")
gender_purchase_count

gender_avg_price = purchase_data.groupby(['Gender']).mean()["Price"].rename("average")
gender_avg_price

gender_total_purchase = purchase_data.groupby(['Gender']).sum()["Price"].rename("sum")
gender_total_purchase

avg_purchase_per_person = gender_total_purchase/gender_purchase_count
avg_purchase_per_person

purchasing_analysis = pd.DataFrame({"Purchase Count": gender_purchase_count,
                                    "Avg Purchase Price": gender_avg_price,
                                    "Total Purchase Value": gender_total_purchase,
                                    "Avg Purchase Total Per Person": avg_purchase_per_person})
purchasing_analysis
# Out:
#                        Purchase Count  Avg Purchase Price  \
# Gender
# Female                            113            3.203009
# Male                              652            3.017853
# Other / Non-Disclosed              15            3.346000
#
#                        Total Purchase Value  Avg Purchase Total Per Person
# Gender
# Female                               361.94                       3.203009
# Male                                1967.64                       3.017853
# Other / Non-Disclosed                 50.19                       3.346000

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Establish bins for ages
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

purchase_data["Age Group"] = pd.cut(purchase_data["Age"], age_bins, labels=group_names)
purchase_data

total_per_age_group = purchase_data.groupby(['Age Group']).count()["SN"].rename("count")
total_per_age_group

age_group_percentages= (total_per_age_group/total_player)*100
age_group_percentages

age_demographics = pd.DataFrame({"Percentage of Players": age_group_percentages,
                                    "Total Count": total_per_age_group})
age_demographics
# Out:
#            Percentage of Players  Total Count
# Age Group
# <10                     3.993056           23
# 10-14                   4.861111           28
# 15-19                  23.611111          136
# 20-24                  63.368056          365
# 25-29                  17.534722          101
# 30-34                  12.673611           73
# 35-39                   7.118056           41
# 40+                     2.256944           13

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
#group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

#purchase_data["Age Group"] = pd.cut(purchase_data["Age"], age_bins, labels=group_names)
#purchase_data

total_per_age_group = purchase_data.groupby(['Age Group']).count()["Purchase ID"].rename("count")
total_per_age_group

average_purchase_price = purchase_data.groupby(['Age Group']).mean()["Price"].rename("mean")
average_purchase_price

total_purchase_value = purchase_data.groupby(['Age Group']).sum()["Price"].rename("sum")
total_purchase_value

avg_purchase_total_per_person = total_purchase_value/total_per_age_group
avg_purchase_total_per_person

purchasing_analysis_table = pd.DataFrame({"Purchase Count": total_per_age_group,
                                          "Avg Purchase Price": average_purchase_price,
                                          "Total Purchase Value": total_purchase_value,
                                         "Avg Purchase Total Per Person": avg_purchase_total_per_person})
purchasing_analysis_table
# Out:
#            Purchase Count  Avg Purchase Price  Total Purchase Value  \
# Age Group
# <10                    23            3.353478                 77.13
# 10-14                  28            2.956429                 82.78
# 15-19                 136            3.035956                412.89
# 20-24                 365            3.052219               1114.06
# 25-29                 101            2.900990                293.00
# 30-34                  73            2.931507                214.00
# 35-39                  41            3.601707                147.67
# 40+                    13            2.941538                 38.24
#
#            Avg Purchase Total Per Person
# Age Group
# <10                             3.353478
# 10-14                           2.956429
# 15-19                           3.035956
# 20-24                           3.052219
# 25-29                           2.900990
# 30-34                           2.931507
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
purchase_count = purchase_data.groupby(['SN']).count()["Purchase ID"].rename("count")
purchase_count

average_purchase_price = purchase_data.groupby(['SN']).mean()["Price"].rename("mean")
average_purchase_price

total_purchase_value = purchase_data.groupby(['SN']).sum()["Price"].rename("sum")
total_purchase_value

top_spenders_table = pd.DataFrame({"Purchase Count": purchase_count,
                              "Average Purchase Price": average_purchase_price,
                              "Total Purchase Value": total_purchase_value})

sort_table = top_spenders_table.sort_values('Purchase Count', ascending=[False])

sort_table.head()
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Iral74                    4                3.405000                 13.62
# Idastidru52               4                3.862500                 15.45
# Asur53                    3                2.480000                  7.44
# Inguron55                 3                3.703333                 11.11

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
Most_popular = purchase_data [["Item ID", "Item Name", "Price"]]
Most_popular.head()

Most_popular_group = Most_popular.groupby(['Item ID','Item Name'])
Most_popular_group.head()

purchase_count = Most_popular.groupby(['Item ID','Item Name']).count()["Price"].rename("count")
purchase_count.head()

item_price = Most_popular.groupby(['Item ID','Item Name']).mean()["Price"].rename("average")
item_price.head()

total_purchase_value = Most_popular.groupby(['Item ID','Item Name']).sum()["Price"].rename("sum")
total_purchase_value

Most_popular_table = pd.DataFrame({"Purchase Count": purchase_count,
                              "Item Prices": item_price,
                              "Total Purchase Value": total_purchase_value})
Most_popular_table

sort_table = Most_popular_table.sort_values('Purchase Count', ascending=[False])

sort_table.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                       Item Prices  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm         4.23
# 145     Fiery Glass Crusader                                 4.58
# 108     Extraction, Quickblade Of Trembling Hands            3.53
# 82      Nirvana                                              4.90
# 19      Pursuit, Cudgel of Necromancy                        1.02
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
sort_table = Most_popular_table.sort_values('Total Purchase Value', ascending=[False])

sort_table.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Item Prices  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm         4.23
# 82      Nirvana                                              4.90
# 145     Fiery Glass Crusader                                 4.58
# 92      Final Critic                                         4.88
# 103     Singed Scalpel                                       4.35
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...
